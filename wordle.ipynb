# %% [markdown]
# # Using regular expressions to help with Wordle

# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/rwcitek/MyBinder.demo/main?labpath=%2FRegular.Expressions%2Fwordle.ipynb)

# %%
import os, sys
import re

# %% [markdown]
# ### Background

# %% [markdown]
# Wordle is a word-guessing game where the program picks a five letter word from its list and you have six tries to guess it.
# That sounds like a pretty big search space for guessing.  I wonder just how big that search space is and if it can be made smaller with the hints that Wordle gives you about previous guesses.

# %%
# NOT using this currently; can't figure out how to do this
def process_letter(letter,color,prev_pattern):
    '''Given a letter and color (gray,yellow,green)
    converts to a reg expression for grep'''
    pattern = ''
    if color == 'gray':
        return color
    elif color == 'yellow':
        return color
    elif color == 'green':
        return color
    else:
        print("Error, need a color of black,yellow, or green")
        sys.exit()
    
    return pattern

# %%
# NOT using this now, using the system grep instead
def grep(pattern,file):
    '''Given and regular expression and a file, will grep through the file
    for the re'''
    for line in open(file, 'r'):
        if re.search(pattern, line):
            print(line)

# %% [markdown]
# Define the dict file and 5 word file

# %%
# start with the system dictionary
dict = '/usr/share/dict/words'
word5 = ' words.5-letters.txt'

# %% [markdown]
# ### Task 1: how big is the search space

# %%
#os.system(f'ls -la {dict}')
os.system(f'wc -l {dict}')
# Out:
#   235886 /usr/share/dict/words
# 0

# %% [markdown]
# About 235k words.
# Of those, I wonder how many are five-letter words.

# %%
# Create the word5 dictionary
expr = '^[a-z]{5}$'
os.system('grep -E "%s" %s >| %s' % (expr,dict,word5))
os.system(f'wc -l {word5}')
# Out:
#     8497 words.5-letters.txt
# 0

# %% [markdown]
# About 8.5k.  That's a lot smaller, but still a pretty big search space.

# %% [markdown]
# ### Task 2: Get long books to get a count of most used words
# - Download text books from https://www.gutenberg.org/
# - prefix books with 'gtbg_' to allow them to be concatenated into long_text.txt

# %%
# Create the long_text.txt by concatentating all the gtbg_ file
long_text = 'long_text.txt'
os.system(f'cat gtbg_* > {long_text}')
os.system(f'wc -l {long_text}')
# Out:
#   169417 long_text.txt
# 0

# %% [markdown]
# #### Create the word count list from a long text
# - This is ALL words, not just 5-letter words
# - 5 letter will be taken care of in the grep with only 5-letter candidates

# %%
# Divide all words on to single lines, with count of occurrences first
word_count = 'word_count.txt'
os.system(f'grep -o -E "\w*" {long_text} | sort | uniq -c | sort -rn > {word_count}')
os.system(f'wc -l {word_count}')
# Out:
#    18742 word_count.txt
# 0

# %% [markdown]
# ### Task 3: Now, make guesses and fill reg expression in if gray, yellow, green

# %% [markdown]
# #### Guesses
# - gray goes in the NOT brackets [^abcde]
# - green goes in its spot as the letter
# - yellow requires more expr terms to put the yellow in the other spots not found

# %%
# adieu -- d yellow
# dorky -- d yellow, o green, y green
candidates = word5
next_list = 'guess'
expr1 = '[^aieurkdpgmlw]owdy'
#expr2 = '[^aieurkd]o[^aieurk]dy'
#expr3 = 
os.system('grep -E "%s" %s >| %s' % (expr1,candidates,next_list))
#os.system('grep -E "%s" %s >> %s' % (expr2,candidates,next_list))
#os.system('grep -E "%s" %s >> %s' % (expr3,candidates,next_list))

# count and uniq the candidate list
os.system(f'wc -l {next_list}')
os.system(f'sort {next_list} | uniq > {next_list}.uniq')
os.system(f'wc -l {next_list}.uniq')
# Out:
#        1 guess
#        1 guess.uniq
# 0

# %% [markdown]
# Now find the most common 5 letter word from the uniq list that matches

# %%
candidates = f'{next_list}.uniq'
#!grep -wf puzzle.vigor2 word_count.txt | sort -rn | head -1
# grep the candidate list from word_count and print out top word
os.system(f'grep -wf {candidates} {word_count} | sort -rn | head -1')
# Out:
# 0

# %%
# if no candidates found, print out the word list
os.system(f'cat {next_list}.uniq')
# Out:
# howdy
# 0
